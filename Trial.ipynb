# %%
# %matplotlib notebook

import numpy as np
import cv2
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.image as mpimg
plt.figure()
img = plt.imread('barbara.png')
plt.imshow(img,cmap='gray')

plt.figure()
img2 = cv2.imread('barbara.png')
plt.imshow(img2)
# cv2.waitKey()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
a=10
b=20
c=a+b
print(a,"+",b,"=",c)
# Out:
# 10 + 20 = 30

# %%
if a==10:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
for count in range (4):
    print('For')
# Out:
# For
# For
# For
# For

# %%
for count in range (10,13):
    print('For')
# Out:
# For
# For
# For

# %%
for count in range (10,-10,-4):
    print('For')
# Out:
# For
# For
# For
# For
# For

# %%
my_list=[]
for count in range (10,20,2):
    my_list.append(count)
print(my_list)

plt.plot(my_list)
plt.show

a=[1,2,3]
print(a)
# Out:
# [10, 12, 14, 16, 18]
# [1, 2, 3]

# %%
# numpy arrays
arr = np.arange(4,10,2)
print(arr)

arr2= np.array(a)
print(arr2)

arr3 = np.array([1,'ch',9.0])
print(arr3)

print(arr3.dtype)
# Out:
# [4 6 8]
# [1 2 3]
# ['1' 'ch' '9.0']
# <U21

# %%
# 2D arrays
mat1 = np.zeros([3,4,5,2])
# print(mat1)
print(mat1.dtype)

# changing datatype of matrix
mat2 = mat1.astype('int32')
print(mat2.dtype)

mat3 = np.zeros([2,5],dtype='int64')
print(mat3.dtype)
# Out:
# float64
# int32
# int64

# %%
# help(np.zeros)
ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-e0d6d43e2b7a> in <module>
#       1 # help(np.zeros)
# ----> 2 ls
#
# NameError: name 'ls' is not defined

# %%
img = mpimg.imread('cameraman.tif')
plt.figure()

imgplot = plt.imshow(img,vmin=0,vmax=255,cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img2 = img.astype('float64')


# Normalize the image
out = (img2-np.min(img2))/(np.max(img2)-np.min(img2))
img_org = out.copy();

out = out + 0.3
out[out>1.0]=1.0
out[out<0.0]=0.0
out_img=np.uint8(out*255)
plt.figure()
imgplot = plt.imshow(img_org,cmap='gray')
plt.show()

# write the image to memory
path = 'cameraman_bright.png'
plt.imsave(path,out_img,cmap='gray',vmax=255,vmin=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# image1=cv2.imread('cameraman.tif')
# cv2.imshow('image1',image1)
# cv2.waitKey()

import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('cameraman.tif')
# plt.imshow(img)
cv2.imshow('image',img)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b6e5ca76feec> in <module>
#      10 # plt.imshow(img)
#      11 cv2.imshow('image',img)
# ---> 12 cv2.waitkey(0)
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'
